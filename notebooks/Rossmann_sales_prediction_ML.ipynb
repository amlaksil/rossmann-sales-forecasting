# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# Load datasets with dtype specifications to handle mixed types
train = pd.read_csv('/content/train.csv', dtype={'StateHoliday': str})
test = pd.read_csv('/content/test.csv', dtype={'StateHoliday': str})
store = pd.read_csv('/content/store.csv')

# %%
train.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Id', 'Store', 'DayOfWeek', 'Date', 'Open', 'Promo', 'StateHoliday',
#        'SchoolHoliday'],
#       dtype='object')

# %%
store.columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %% [markdown]
# # Handle missing values

# %%
# 1. CompetitionDistance
median_competition_distance = store['CompetitionDistance'].median()
store['CompetitionDistance'].fillna(median_competition_distance, inplace=True)

# %%
# 2. CompetitionOpenSinceMonth
mode_competition_open_since_month = store['CompetitionOpenSinceMonth'].mode()[0]
store['CompetitionOpenSinceMonth'].fillna(mode_competition_open_since_month, inplace=True)

# %%
# 3. CompetitionOpenSinceYear
mode_competition_open_since_year = store['CompetitionOpenSinceYear'].mode()[0]
store['CompetitionOpenSinceYear'].fillna(mode_competition_open_since_year, inplace=True)

# %%
# 4. Promo2SinceWeek
mode_promo2_since_week = store['Promo2SinceWeek'].mode()[0]
store['Promo2SinceWeek'].fillna(mode_promo2_since_week, inplace=True)

# %%
# 5. Promo2SinceYear
mode_promo2_since_year = store['Promo2SinceYear'].mode()[0]
store['Promo2SinceYear'].fillna(mode_promo2_since_year, inplace=True)

# %%
# 6. PromoInterval
store['PromoInterval'].fillna('None', inplace=True)

# %% [markdown]
# For the missing values in the Open column of the test dataset, we can impute them based on some logical assumptions or patterns observed in the data. One common approach is to assume that stores are open if there is no explicit indication that they are closed.

# %%
test['Open'].fillna(1, inplace=True)
test.isnull().sum()
# Out:
# Id               0
# Store            0
# DayOfWeek        0
# Date             0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
store.isnull().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Id               0
# Store            0
# DayOfWeek        0
# Date             0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0             14.0           2011.0
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0             14.0           2011.0
# 4                    2015.0       0             14.0           2011.0
#
#      PromoInterval
# 0             None
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3             None
# 4             None

# %%
# Convert 'Date' column to datetime
train['Date'] = pd.to_datetime(train['Date'])
test['Date'] = pd.to_datetime(test['Date'])

# %%
train.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                       11.0                    2007.0       1
# 2                       12.0                    2006.0       1
# 3                        9.0                    2009.0       0
# 4                        4.0                    2015.0       0
#
#    Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0             14.0           2011.0             None
# 1             13.0           2010.0  Jan,Apr,Jul,Oct
# 2             14.0           2011.0  Jan,Apr,Jul,Oct
# 3             14.0           2011.0             None
# 4             14.0           2011.0             None

# %%
test.head()
# Out:
#    Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  SchoolHoliday  \
# 0   1      1          4 2015-09-17   1.0      1            0              0
# 1   2      3          4 2015-09-17   1.0      1            0              0
# 2   3      7          4 2015-09-17   1.0      1            0              0
# 3   4      8          4 2015-09-17   1.0      1            0              0
# 4   5      9          4 2015-09-17   1.0      1            0              0
#
#   StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0         c          a               1270.0                        9.0
# 1         a          a              14130.0                       12.0
# 2         a          c              24000.0                        4.0
# 3         a          a               7520.0                       10.0
# 4         a          c               2030.0                        8.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0             14.0           2011.0
# 1                    2006.0       1             14.0           2011.0
# 2                    2013.0       0             14.0           2011.0
# 3                    2014.0       0             14.0           2011.0
# 4                    2000.0       0             14.0           2011.0
#
#      PromoInterval
# 0             None
# 1  Jan,Apr,Jul,Oct
# 2             None
# 3             None
# 4             None

# %%
def extract_date_features(df):
    df['Year'] = df['Date'].dt.year
    df['Month'] = df['Date'].dt.month
    df['Day'] = df['Date'].dt.day
    df['DayOfWeek'] = df['Date'].dt.dayofweek
    df['IsWeekend'] = df['DayOfWeek'] >= 5
    df['WeekOfYear'] = df['Date'].dt.isocalendar().week
    df['Quarter'] = df['Date'].dt.quarter
    df['IsMonthStart'] = df['Date'].dt.is_month_start
    df['IsMonthEnd'] = df['Date'].dt.is_month_end
    df['IsQuarterStart'] = df['Date'].dt.is_quarter_start
    df['IsQuarterEnd'] = df['Date'].dt.is_quarter_end

    # Extract holiday dates
    holiday_dates = df[df['StateHoliday'] != '0']['Date'].sort_values().unique()

    # Convert the array to a pandas Series for vectorized operations
    holiday_series = pd.Series(holiday_dates)

    # Initialize arrays for results
    days_to_holiday = np.full(len(df), np.nan)
    days_after_holiday = np.full(len(df), np.nan)

    # Use searchsorted to find the indices of the next and previous holidays
    idx_next_holiday = np.searchsorted(holiday_series, df['Date'], side='left')
    idx_prev_holiday = np.searchsorted(holiday_series, df['Date'], side='right') - 1

    # Calculate days to the next holiday
    valid_next_holiday = idx_next_holiday < len(holiday_series)
    days_to_holiday[valid_next_holiday] = (holiday_series.iloc[idx_next_holiday[valid_next_holiday]].values - df['Date'][valid_next_holiday].values) / np.timedelta64(1, 'D')

    # Calculate days after the last holiday
    valid_prev_holiday = idx_prev_holiday >= 0
    days_after_holiday[valid_prev_holiday] = (df['Date'][valid_prev_holiday].values - holiday_series.iloc[idx_prev_holiday[valid_prev_holiday]].values) / np.timedelta64(1, 'D')

    # Assign results back to the DataFrame
    df['DaysToHoliday'] = days_to_holiday
    df['DaysAfterHoliday'] = days_after_holiday

    return df

# %%
extract_date_features(train)
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          4 2015-07-31   5263        555     1      1
# 1            2          4 2015-07-31   6064        625     1      1
# 2            3          4 2015-07-31   8314        821     1      1
# 3            4          4 2015-07-31  13995       1498     1      1
# 4            5          4 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1111          1 2013-01-01      0          0     0      0
# 1017205   1112          1 2013-01-01      0          0     0      0
# 1017206   1113          1 2013-01-01      0          0     0      0
# 1017207   1114          1 2013-01-01      0          0     0      0
# 1017208   1115          1 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday  Year  ...  Day  IsWeekend  WeekOfYear  \
# 0                  0              1  2015  ...   31      False          31
# 1                  0              1  2015  ...   31      False          31
# 2                  0              1  2015  ...   31      False          31
# 3                  0              1  2015  ...   31      False          31
# 4                  0              1  2015  ...   31      False          31
# ...              ...            ...   ...  ...  ...        ...         ...
# 1017204            a              1  2013  ...    1      False           1
# 1017205            a              1  2013  ...    1      False           1
# 1017206            a              1  2013  ...    1      False           1
# 1017207            a              1  2013  ...    1      False           1
# 1017208            a              1  2013  ...    1      False           1
#
#          Quarter  IsMonthStart  IsMonthEnd  IsQuarterStart  IsQuarterEnd  \
# 0              3         False        True           False         False
# 1              3         False        True           False         False
# 2              3         False        True           False         False
# 3              3         False        True           False         False
# 4              3         False        True           False         False
# ...          ...           ...         ...             ...           ...
# 1017204        1          True       False            True         False
# 1017205        1          True       False            True         False
# 1017206        1          True       False            True         False
# 1017207        1          True       False            True         False
# 1017208        1          True       False            True         False
#
#          DaysToHoliday  DaysAfterHoliday
# 0                  NaN              57.0
# 1                  NaN              57.0
# 2                  NaN              57.0
# 3                  NaN              57.0
# 4                  NaN              57.0
# ...                ...               ...
# 1017204            0.0               0.0
# 1017205            0.0               0.0
# 1017206            0.0               0.0
# 1017207            0.0               0.0
# 1017208            0.0               0.0
#
# [1017209 rows x 21 columns]

# %%
extract_date_features(test)
# Out:
#           Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  \
# 0          1      1          3 2015-09-17   1.0      1            0
# 1          2      3          3 2015-09-17   1.0      1            0
# 2          3      7          3 2015-09-17   1.0      1            0
# 3          4      8          3 2015-09-17   1.0      1            0
# 4          5      9          3 2015-09-17   1.0      1            0
# ...      ...    ...        ...        ...   ...    ...          ...
# 41083  41084   1111          5 2015-08-01   1.0      0            0
# 41084  41085   1112          5 2015-08-01   1.0      0            0
# 41085  41086   1113          5 2015-08-01   1.0      0            0
# 41086  41087   1114          5 2015-08-01   1.0      0            0
# 41087  41088   1115          5 2015-08-01   1.0      0            0
#
#        SchoolHoliday  Year  Month  Day  IsWeekend  WeekOfYear  Quarter  \
# 0                  0  2015      9   17      False          38        3
# 1                  0  2015      9   17      False          38        3
# 2                  0  2015      9   17      False          38        3
# 3                  0  2015      9   17      False          38        3
# 4                  0  2015      9   17      False          38        3
# ...              ...   ...    ...  ...        ...         ...      ...
# 41083              0  2015      8    1       True          31        3
# 41084              0  2015      8    1       True          31        3
# 41085              0  2015      8    1       True          31        3
# 41086              0  2015      8    1       True          31        3
# 41087              1  2015      8    1       True          31        3
#
#        IsMonthStart  IsMonthEnd  IsQuarterStart  IsQuarterEnd  DaysToHoliday  \
# 0             False       False           False         False            NaN
# 1             False       False           False         False            NaN
# 2             False       False           False         False            NaN
# 3             False       False           False         False            NaN
# 4             False       False           False         False            NaN
# ...             ...         ...             ...           ...            ...
# 41083          True       False           False         False           14.0
# 41084          True       False           False         False           14.0
# 41085          True       False           False         False           14.0
# 41086          True       False           False         False           14.0
# 41087          True       False           False         False           14.0
#
#        DaysAfterHoliday
# 0                  33.0
# 1                  33.0
# 2                  33.0
# 3                  33.0
# 4                  33.0
# ...                 ...
# 41083               NaN
# 41084               NaN
# 41085               NaN
# 41086               NaN
# 41087               NaN
#
# [41088 rows x 20 columns]

# %%
# Merge store information
train = train.merge(store, on='Store', how='left')
test = test.merge(store, on='Store', how='left')

# %%
train.dtypes
# Out:
# Store                                 int64
# DayOfWeek                             int32
# Date                         datetime64[ns]
# Sales                                 int64
# Customers                             int64
# Open                                  int64
# Promo                                 int64
# StateHoliday                         object
# SchoolHoliday                         int64
# Year                                  int32
# Month                                 int32
# Day                                   int32
# IsWeekend                              bool
# WeekOfYear                           UInt32
# Quarter                               int32
# IsMonthStart                           bool
# IsMonthEnd                             bool
# IsQuarterStart                         bool
# IsQuarterEnd                           bool
# DaysToHoliday                       float64
# DaysAfterHoliday                    float64
# StoreType                            object
# Assortment                           object
# CompetitionDistance                 float64
# CompetitionOpenSinceMonth           float64
# CompetitionOpenSinceYear            float64
# Promo2                                int64
# Promo2SinceWeek                     float64
# Promo2SinceYear                     float64
# PromoInterval                        object
# dtype: object

# %%
test.dtypes
# Out:
# Id                                    int64
# Store                                 int64
# DayOfWeek                             int32
# Date                         datetime64[ns]
# Open                                float64
# Promo                                 int64
# StateHoliday                         object
# SchoolHoliday                         int64
# Year                                  int32
# Month                                 int32
# Day                                   int32
# IsWeekend                              bool
# WeekOfYear                           UInt32
# Quarter                               int32
# IsMonthStart                           bool
# IsMonthEnd                             bool
# IsQuarterStart                         bool
# IsQuarterEnd                           bool
# DaysToHoliday                       float64
# DaysAfterHoliday                    float64
# StoreType                            object
# Assortment                           object
# CompetitionDistance                 float64
# CompetitionOpenSinceMonth           float64
# CompetitionOpenSinceYear            float64
# Promo2                                int64
# Promo2SinceWeek                     float64
# Promo2SinceYear                     float64
# PromoInterval                        object
# dtype: object

# %%
def preprocess_data(df):
  # Map values
  mapping = {'0': 1, 'a': 0, 'b': 0, 'c': 0}
  df['StateHoliday'] = df['StateHoliday'].replace(mapping)
  columns=['StoreType', 'Assortment', 'PromoInterval']

  # Convert categorical features to numeric using one-hot encoding
  dataset = pd.get_dummies(df, columns=columns, drop_first=True)
  return dataset

# %%
train = preprocess_data(train)

# %%
test = preprocess_data(test)

# %%
train.dtypes
# Out:
# Store                                      int64
# DayOfWeek                                  int32
# Date                              datetime64[ns]
# Sales                                      int64
# Customers                                  int64
# Open                                       int64
# Promo                                      int64
# StateHoliday                               int64
# SchoolHoliday                              int64
# Year                                       int32
# Month                                      int32
# Day                                        int32
# IsWeekend                                   bool
# WeekOfYear                                UInt32
# Quarter                                    int32
# IsMonthStart                                bool
# IsMonthEnd                                  bool
# IsQuarterStart                              bool
# IsQuarterEnd                                bool
# DaysToHoliday                            float64
# DaysAfterHoliday                         float64
# CompetitionDistance                      float64
# CompetitionOpenSinceMonth                float64
# CompetitionOpenSinceYear                 float64
# Promo2                                     int64
# Promo2SinceWeek                          float64
# Promo2SinceYear                          float64
# StoreType_b                                 bool
# StoreType_c                                 bool
# StoreType_d                                 bool
# Assortment_b                                bool
# Assortment_c                                bool
# PromoInterval_Jan,Apr,Jul,Oct               bool
# PromoInterval_Mar,Jun,Sept,Dec              bool
# PromoInterval_None                          bool
# dtype: object

# %%
test.dtypes
# Out:
# Id                                         int64
# Store                                      int64
# DayOfWeek                                  int32
# Date                              datetime64[ns]
# Open                                     float64
# Promo                                      int64
# StateHoliday                               int64
# SchoolHoliday                              int64
# Year                                       int32
# Month                                      int32
# Day                                        int32
# IsWeekend                                   bool
# WeekOfYear                                UInt32
# Quarter                                    int32
# IsMonthStart                                bool
# IsMonthEnd                                  bool
# IsQuarterStart                              bool
# IsQuarterEnd                                bool
# DaysToHoliday                            float64
# DaysAfterHoliday                         float64
# CompetitionDistance                      float64
# CompetitionOpenSinceMonth                float64
# CompetitionOpenSinceYear                 float64
# Promo2                                     int64
# Promo2SinceWeek                          float64
# Promo2SinceYear                          float64
# StoreType_b                                 bool
# StoreType_c                                 bool
# StoreType_d                                 bool
# Assortment_b                                bool
# Assortment_c                                bool
# PromoInterval_Jan,Apr,Jul,Oct               bool
# PromoInterval_Mar,Jun,Sept,Dec              bool
# PromoInterval_None                          bool
# dtype: object

# %%
# Calculate the correlation matrix
correlation_matrix = train.corr()

# %%
correlation_matrix['Sales']
# Out:
# Store                             0.005126
# DayOfWeek                        -0.462125
# Date                              0.041904
# Sales                             1.000000
# Customers                         0.894711
# Open                              0.678472
# Promo                             0.452345
# StateHoliday                      0.254216
# SchoolHoliday                     0.085124
# Year                              0.023519
# Month                             0.048768
# Day                              -0.011612
# IsWeekend                        -0.450152
# WeekOfYear                        0.052946
# Quarter                           0.043984
# IsMonthStart                     -0.053450
# IsMonthEnd                        0.047112
# IsQuarterStart                   -0.013222
# IsQuarterEnd                      0.027899
# DaysToHoliday                     0.015372
# DaysAfterHoliday                  0.055244
# CompetitionDistance              -0.018869
# CompetitionOpenSinceMonth        -0.023226
# CompetitionOpenSinceYear          0.008740
# Promo2                           -0.091040
# Promo2SinceWeek                  -0.003562
# Promo2SinceYear                  -0.040708
# StoreType_b                       0.139940
# StoreType_c                      -0.005140
# StoreType_d                      -0.022854
# Assortment_b                      0.065473
# Assortment_c                      0.068772
# PromoInterval_Jan,Apr,Jul,Oct    -0.034946
# PromoInterval_Mar,Jun,Sept,Dec   -0.053267
# PromoInterval_None                0.091040
# Name: Sales, dtype: float64

# %%
# Set the threshold value
threshold = 0.05

# %%
# Filter the columns based on the threshold
filtered_columns = correlation_matrix['Sales'][abs(correlation_matrix['Sales']) >= threshold].sort_values(ascending=False)

# %%
filtered_columns
# Out:
# Sales                             1.000000
# Customers                         0.894711
# Open                              0.678472
# Promo                             0.452345
# StateHoliday                      0.254216
# StoreType_b                       0.139940
# PromoInterval_None                0.091040
# SchoolHoliday                     0.085124
# Assortment_c                      0.068772
# Assortment_b                      0.065473
# DaysAfterHoliday                  0.055244
# WeekOfYear                        0.052946
# PromoInterval_Mar,Jun,Sept,Dec   -0.053267
# IsMonthStart                     -0.053450
# Promo2                           -0.091040
# IsWeekend                        -0.450152
# DayOfWeek                        -0.462125
# Name: Sales, dtype: float64

# %%
# Extract the column names
filtered_column_names = filtered_columns.index.tolist()
filtered_column_names[1:]
# Out:
# ['Customers',
#  'Open',
#  'Promo',
#  'StateHoliday',
#  'StoreType_b',
#  'PromoInterval_None',
#  'SchoolHoliday',
#  'Assortment_c',
#  'Assortment_b',
#  'DaysAfterHoliday',
#  'WeekOfYear',
#  'PromoInterval_Mar,Jun,Sept,Dec',
#  'IsMonthStart',
#  'Promo2',
#  'IsWeekend',
#  'DayOfWeek']

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Separate target variable
X_test = test[filtered_column_names[2:]]
# y_test = test['Sales']
# Separate target variable
X_train = train[filtered_column_names[2:]]
y_train = train['Sales']

# Scale all input features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train) # Fit and transform X_train
# Scale all input features
X_test_scaled = scaler.transform(X_test) # Transform X_test using the fitted scaler

# %%
y_train
# Out:
# 0           5263
# 1           6064
# 2           8314
# 3          13995
# 4           4822
#            ...
# 1017204        0
# 1017205        0
# 1017206        0
# 1017207        0
# 1017208        0
# Name: Sales, Length: 1017209, dtype: int64

# %%
X_train
# Out:
#          Open  Promo  StateHoliday  StoreType_b  PromoInterval_None  \
# 0           1      1             1        False                True
# 1           1      1             1        False               False
# 2           1      1             1        False               False
# 3           1      1             1        False                True
# 4           1      1             1        False                True
# ...       ...    ...           ...          ...                 ...
# 1017204     0      0             0        False               False
# 1017205     0      0             0        False                True
# 1017206     0      0             0        False                True
# 1017207     0      0             0        False                True
# 1017208     0      0             0        False               False
#
#          SchoolHoliday  Assortment_c  Assortment_b  DaysAfterHoliday  \
# 0                    1         False         False              57.0
# 1                    1         False         False              57.0
# 2                    1         False         False              57.0
# 3                    1          True         False              57.0
# 4                    1         False         False              57.0
# ...                ...           ...           ...               ...
# 1017204              1         False         False               0.0
# 1017205              1          True         False               0.0
# 1017206              1          True         False               0.0
# 1017207              1          True         False               0.0
# 1017208              1          True         False               0.0
#
#          WeekOfYear  PromoInterval_Mar,Jun,Sept,Dec  IsMonthStart  Promo2  \
# 0                31                           False         False       0
# 1                31                           False         False       1
# 2                31                           False         False       1
# 3                31                           False         False       0
# 4                31                           False         False       0
# ...             ...                             ...           ...     ...
# 1017204           1                           False          True       1
# 1017205           1                           False          True       0
# 1017206           1                           False          True       0
# 1017207           1                           False          True       0
# 1017208           1                            True          True       1
#
#          IsWeekend  DayOfWeek
# 0            False          4
# 1            False          4
# 2            False          4
# 3            False          4
# 4            False          4
# ...            ...        ...
# 1017204      False          1
# 1017205      False          1
# 1017206      False          1
# 1017207      False          1
# 1017208      False          1
#
# [1017209 rows x 15 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline

# Create pipeline
pipeline = Pipeline(steps=[('regressor', RandomForestRegressor(n_estimators=100, random_state=42))])

# %%
model = pipeline.fit(X_train_scaled, y_train)

# %%
model
# Out:
# Pipeline(steps=[('regressor', RandomForestRegressor(random_state=42))])

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

# Define the model

# Perform cross-validation and get the scores
cv_scores = cross_val_score(pipeline, X_train_scaled, y_train, cv=5, scoring='neg_mean_squared_error')

# Convert negative MSE to positive and take the square root to get RMSE
rmse_scores = (-cv_scores)**0.5

# Print the scores and the mean RMSE
print("Cross-validation RMSE scores:", rmse_scores)
print("Mean RMSE:", rmse_scores.mean())
# Out:
# Cross-validation RMSE scores: [2390.0197901  2487.34799267 2353.49090255 2506.34545231 2409.21156865]
# Mean RMSE: 2429.2831412552277
